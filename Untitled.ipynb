# %%
import pandas as pd
import requests
import numpy as np
import re
import spacy
import torch
import dspy
from transformers import AutoTokenizer, AutoModelForCausalLM
from sentence_transformers import SentenceTransformer
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import ndcg_score
import numpy as np
import random
import faiss
from sklearn.preprocessing import normalize
random.seed(42)
import spacy
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import dspy
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
import time
# Out:
# WARNING:tensorflow:From C:\Users\emiel\.conda\envs\DSP-project\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\emiel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\emiel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
api_key = "AIzaSyA5k2l94SzBWIxyCwveRFfV7ZTc9k4F_3c"

# %%
query = 'David Mitchell Cloud atlas'
descriptions = []
api_key = "AIzaSyA5k2l94SzBWIxyCwveRFfV7ZTc9k4F_3c" 
url = (
f"https://www.googleapis.com/books/v1/volumes"
f"?q={query.replace(' ', '+')}"
f"&langRestrict=en"
f"&filter=ebooks"
f"&key={api_key}"
)

headers = {
    "Accept-Language": "en"
}
response = requests.get(url, headers=headers)
    
if response.status_code == 200:
    data = response.json()
    total_items = data.get("totalItems", 0)

    for item in data.get("items", [])[:1]:
        try:
            descriptions.append(item['volumeInfo']['description'])
        except KeyError:
            descriptions.append(np.NaN)
else:
    print(f"Error: {response.status_code}")
    descriptions.append(np.NaN)

# %%
import wikipediaapi

def get_book_page_names(q):
    headers = {
        'User-Agent': 'my-python-script/1.0 (your-email@example.com)' 
    }
    
    search_url = f"https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch={q}&utf8=&format=json"
    search_response = requests.get(search_url, headers=headers).json()
    try:
     
        page_titles = [search_response['query']['search'][i]['title'] for i in range(len(search_response['query']['search']))][:5]
        
    except IndexError:
        print(q)
        page_titles = [np.NaN]
    
    return page_titles

def get_plot(q):
    wiki_page_titles = get_book_page_names(q)
    wiki_wiki = wikipediaapi.Wikipedia(
        language='en', 
        user_agent="YourAppName/1.0 (your-email@example.com)" 
    )

    for wiki_page_title in wiki_page_titles:
        page = wiki_wiki.page(wiki_page_title)

        def get_section_text(section):
            text = section.text
            for subsection in section.sections:
                text += " " + get_section_text(subsection)
            return text
    
        for plot_indicator in ['Plot', 'Plot summary']:
            plot_section = page.section_by_title(plot_indicator)
            if plot_section:
                return get_section_text(plot_section).strip()
    
    return np.NaN

author = "George Saunders"
title = "Lincoln in the Bardo"
get_plot(f"{title} (novel) by {author}")
# Out:
# 'Lincoln in the Bardo is set in 1862, unfolding over a single night following Willie Lincoln\'s death. As Abraham Lincoln mourns at his son\'s crypt, he unwittingly enters a supernatural realm inhabited by spirits unable to move on due to unresolved attachments. The spirits, including Hans Vollman, Roger Bevins III, and Reverend Everly Thomas, narrate the story in fragmented monologues. They observe Lincoln\'s grief and attempt to help Willie transition to the afterlife, fearing that his lingering attachment to his father may trap him in this state indefinitely.\nIn a climactic sequence, the spirits briefly inhabit Lincoln\'s body, experiencing his grief while urging him to let go of Willie. This moment allows many of them to confront their own deaths and transition through a phenomenon called "matterlightblooming". Willie accepts his fate and departs, enabling Lincoln to begin healing.'

# %%
df = pd.read_csv("data/goodreads_library_export.csv")

# %%
def remove_parentheses_text(text):
    return re.sub(r'\s*\([^)]*\)', '', text).strip()

# %%
df['Title'] = df["Title"].apply(remove_parentheses_text)

# %%
df["Title Author"] = df["Title"] + " (novel)" +" "+ df["Author"]

# %%
df = df[df["Exclusive Shelf"] == "read"]

# %%
df['Description'] = df['Title Author'].apply(lambda x: get_plot(x))

# %%
df
# Out:
#      level_0  index    Book Id                   Title           Author  \
# 0          0      2   33852053                  Gnomon    Nick Harkaway
# 1          1      8   22237161             The Sellout      Paul Beatty
# 2          2     10   12991188            Train Dreams    Denis Johnson
# 3          3     12  214331246  Sunrise on the Reaping  Suzanne Collins
# 4          4     13   25300956          Royal Assassin       Robin Hobb
# ..       ...    ...        ...                     ...              ...
# 308      308    648    2767052        The Hunger Games  Suzanne Collins
# 309      309    649   12279616        Ready Player One     Ernest Cline
# 310      310    650   13265138          The Death Cure    James Dashner
# 311      311    651   10193699       The Scorch Trials    James Dashner
# 312      312    652    7805064         The Maze Runner    James Dashner
#
#            Author l-f Additional Authors           ISBN            ISBN13  \
# ...

# %%
df = df.dropna(subset=['Description']).reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21360\177169550.py in ?()
# ----> 1 df = df.dropna(subset=['Description']).reset_index()
#
# ~\.conda\envs\DSP-project\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\.conda\envs\DSP-project\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
# ...

# %%
texts = df.Description.tolist()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
texts.insert(0,df.iloc[1].Description)

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2", device=device)
embedder = dspy.Embedder(model.encode)

# %%
embeddings = embedder(texts)

# %%
df['similarity'] = cosine_similarity(embeddings[:1],embeddings[1:]).tolist()[0]

# %%
df.sort_values(by='similarity', ascending = False).Title.tolist()[:20]
# Out:
# ['The Sellout',
#  'The Picture in the House',
#  'Blood Meridian, or, the Evening Redness in the West',
#  'The Catcher in the Rye',
#  'Revival',
#  'The Ocean at the End of the Lane',
#  'To Kill a Mockingbird',
#  'Slaughterhouse-Five',
#  'Wizard and Glass',
#  '11/22/63',
#  'Fahrenheit 451',
#  'The Sirens of Titan',
#  'Elantris',
#  'The Hope of Elantris',
#  'Lincoln in the Bardo',
#  'The Bone Clocks',
#  'Too Like the Lightning',
#  'The Gunslinger',
#  'The Shadow of the Wind',
#  'Something Wicked This Way Comes']

# %%
text = df.iloc[27].Description

# %%
text = "During the Great Depression in California, two migrant field workers – George Milton, an intelligent but uneducated man, and Lennie Small, a bulky, strong but mentally disabled man – are on their way from Soledad to another part of the state. They share a dream of settling down on their own piece of land. Lennie's part of the dream is merely to care for and pet rabbits. He loves touching soft animals, although he always accidentally kills them by petting them too hard. George constantly retells the dream, which is one of Lennie's favorite stories. They fled from Weed after Lennie grabbed a young woman's skirt because he thought it was pretty. He would not let go, because he holds on tighter when stressed. This led to an accusation of rape and a mob forming to find and lynch Lennie. Throughout the introduction, it becomes clear that Lennie relies on George because he is unable to function independently.After they are hired at a farm, Curley, the Boss's small, aggressive son, confronts the pair. Curley, who has a Napoleon complex, dislikes larger men, and targets Lennie. Lennie is instantly attracted to Curley's flirtatious and provocative wife, which also poses a problem. In contrast, the pair meets Candy, an elderly ranch handyman with one hand and a loyal dog, and Slim, an intelligent and gentle jerkline-skinner whose dog has recently had a litter of puppies. Slim gives puppies to Lennie and to Candy, whose loyal, accomplished sheep dog was put down by fellow ranch-hand Carlson.In spite of problems, their dream leaps towards reality when Candy offers to pitch in $350 toward the purchase of a farm, in return for permission to live with them. They will be able to buy a farm at the end of the month. The trio are ecstatic, but their joy is overshadowed when Curley attacks Lennie, who defends himself by easily crushing Curley's fist while urged on by George.Nevertheless, George feels more relaxed. He even leaves Lennie behind on the ranch while he goes into town with the other hands. Lennie wanders into the stable, and chats with Crooks, the bitter, yet educated stable hand, who is isolated from the other workers because he is black. Candy finds them and they discuss their plans for the farm with Crooks, who cannot resist asking if he can hoe a garden patch on the farm, even though he scorns the possibility of the dream coming true. Curley's wife makes another appearance and flirts with the men, especially Lennie. However, she shows her spiteful side when she belittles them and threatens to have Crooks lynched. They hear the ranch hands returning, and she leaves.The next day, Lennie accidentally kills his puppy while stroking it. Curley's wife enters the barn and tries to speak to him, admitting that she is lonely. Her dreams of becoming a movie star have been crushed. She finds out about Lennie's love of soft things and offers to let him stroke her hair, but when she feels his strength, she panics and begins to scream. Lennie becomes frightened and unintentionally breaks her neck. He runs away. When the other ranch hands find the corpse, they form a lynch mob intent on killing him, sending for the police before beginning the search. George quickly realizes that their dream is at an end and hurries to find Lennie, hoping he will be at the meeting place they designated in case he got into trouble.George finds Lennie at the meeting spot, and the two sit together while George retells the beloved story of the dream, although he now knows it will never happen. George hears the lynch mob coming and shoots Lennie, giving him a more merciful death than the one he would receive at the hands of the mob. Curley, Slim, and Carlson arrive seconds later. Only Slim understands what has happened. He leads George away, trying to console him. Curley and Carlson look on, neither understanding why Slim and George are feeling the way they are. "

# %%
from ollama import chat
from pydantic import BaseModel, Field
from typing import Literal, Optional, List

class Character(BaseModel):
    name: str
    role: Optional[str]
    age: Optional[int]
    backstory: Optional[str]
    beliefs: Optional[list[str]]
    weaknesses: Optional[list[str]]
    strengths: Optional[list[str]]
    motivations: Optional[list[str]]
    character_arc: Optional[str] = Field(None, description="Describes how the character changes over the story")
    #actantial_role: Literal['Subject', 'Object', 'Helper', 'Opponent', 'Sender', 'Receiver'] = None

class Setting(BaseModel):
    time_periods: list[str]
    locations: list[str] 
    cultural_context: list[str]

class Plot(BaseModel):

    #timeline_of_events: list[str] = Field(description = (
    #    "a sequenced list of very brief event descriptions"
    #))
    
    conflict: Optional[Literal['person vs. person', 'person vs. self', 'person vs. nature', 'person vs.society']]

    story_exposition: Optional[str]
    story_rising_action: Optional[str]
    story_climax: Optional[str]
    story_falling_actions: Optional[str]
    story_denouement: Optional[str]
    
class Theme(BaseModel):
    main_themes: Optional[list[str]]
    secondary_themes: Optional[list[str]]
    
class Other(BaseModel):
    main_genres: Optional[list[str]]
    sub_genres: Optional[list[str]]
    content_warnings: Optional[list[str]]
    writing_style: Optional[str]
    point_of_view: Optional[Literal['First-person narrator', 'Third-person limited narrator', 'Third-person omniscient narrator']]
    
class Elements(BaseModel):
    characters: list[Character]
    setting: Setting
    plot: Plot
    theme: Theme
    other: Other

# %%
# %%time
response = chat(
    messages=[
    {"role": "system", "content": f"Return as a JSON object"},
    {"role": "user", "content": text}
    ],
    model='llama3.1:8b',
    format=Elements.model_json_schema(),
    options = {'temperature':0}
)

elements = Elements.model_validate_json(response.message.content)
print(elements)
# Out:
# characters=[Character(name='George Milton', role='Migrant field worker', age=None, backstory='Intelligent but uneducated man who shares a dream of settling down on his own piece of land with Lennie.', beliefs=['dreams of owning a farm'], weaknesses=['uneducated'], strengths=['intelligent'], motivations=['to settle down and own a farm'], character_arc=None), Character(name='Lennie Small', role='Migrant field worker', age=None, backstory='Bulky, strong but mentally disabled man who shares a dream of settling down on his own piece of land with George.', beliefs=['dreams of owning a farm'], weaknesses=['mentally disabled'], strengths=['strong'], motivations=['to settle down and own a farm'], character_arc=None), Character(name='Curley', role="Boss's son", age=None, backstory='Small, aggressive man who dislikes larger men.', beliefs=['dislikes larger men'], weaknesses=['aggressive'], strengths=['strong'], motivations=['to assert dominance over others'], character_arc=None), Character(name
# ...

# %%
# %%time
lm = dspy.LM('ollama_chat/llama3.1:8b', api_base='http://localhost:11434', api_key='')
dspy.configure(lm=lm)
from typing import Literal
class ExtractNarrativeElements(dspy.Signature):
    """This function extracts different narrative elements from a story."""
    text: str = dspy.InputField()
    
    genres: list[str] = dspy.OutputField()
    main_themes: list[str] = dspy.OutputField()
    secondary_themes: list[str] = dspy.OutputField()
    tertiary_themes: list[str] = dspy.OutputField()
    
    characters: list[dict]= dspy.OutputField(desc="Information about all major characters including: beliefs, name, role, backstory, weaknesses, strengths, motivations. If not found they can be None.")

    
    time_periods: list[str] = dspy.OutputField(desc="All time periods in which the story take splace")
    geographical_locations: list[str] = dspy.OutputField(desc="All concrete geographical locations in which the story takes place")
    abstract_locations: list[str] = dspy.OutputField(desc="All abstract locations in which the story takes place")
    cultural_context: list[str] = dspy.OutputField(desc="Descriptions of the various cultural contexts")
    #sentiment: Literal['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'] = dspy.OutputField()

    inciting_incident: str = dspy.OutputField()
    timeline_of_events: str = dspy.OutputField()

module = dspy.Predict(ExtractNarrativeElements)

response = module(text=text)
for x in response:
    print()
    print(response[x])
